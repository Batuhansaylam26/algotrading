# %%
import yfinance as yf
import pandas as pd 
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import ta as ta2
import tti
import plotly.graph_objects as go

# %%
data = yf.download('AKBNK.IS',interval="1D")
data=data.rename({"High":"high","Low":"low","Close":"close","Open":"open","Adj Close":"adj close","Volume":"volume"},axis=1)

data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  open       high        low      close      adj close  \
# Date
# 2000-05-10   6.137479   6.410256   6.001091   6.137479 -125640.015625
# 2000-05-11   6.137479   6.273867   5.864702   6.137479 -125640.015625
# 2000-05-12   6.273867   6.410256   6.001091   6.273867 -128432.039062
# 2000-05-15   6.137479   6.273867   6.001091   6.137479 -125640.015625
# 2000-05-16   6.001091   6.137479   5.864702   6.001091 -122848.046875
# ...               ...        ...        ...        ...            ...
# 2023-10-09  33.180000  33.380001  32.160000  32.259998      32.259998
# 2023-10-10  32.680000  33.360001  32.439999  33.139999      33.139999
# 2023-10-11  33.279999  33.959999  33.099998  33.320000      33.320000
# 2023-10-12  33.680000  34.340000  32.299999  32.919998      32.919998
# 2023-10-13  32.959999  33.000000  31.459999  31.600000      31.600000
#
#                volume
# Date
# 2000-05-10    1284067
# 2000-05-11     608846
# 2000-05-12    2283592
# 2000-05-15     122956
# 2000-05-16    1331524
# ...               ...
# 2023-10-09   96530249
# 2023-10-10   71195544
# 2023-10-11   82944842
# 2023-10-12  109831125
# 2023-10-13   80019623
#
# [5887 rows x 6 columns]

# %%
figure=go.Figure(
    go.Scatter(x=data.index,y=data.close)
)
figure.show()
